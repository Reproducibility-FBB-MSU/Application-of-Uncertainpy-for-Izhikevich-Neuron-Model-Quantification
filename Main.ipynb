# %% [markdown]
# # Тестирование модуля Uncertainpy на примере модели нейрона Ижикевича

# %% [markdown]
# ПРЕДУПРЕЖДЕНИЕ: При первом запуске скрипта сразу после установки модуля Uncertainpy может возникнуть следующая ошибка:
# File "<path to packages>/site-packages/chaospy/quad/interface.py", line 5, in <module>
#     from scipy.misc import comb
# ImportError: cannot import name 'comb'
#
#     Решается это следующим образом: необходимо открыть файл interface.py и изменить в 5 строчке scipy.misc
#     на scipy.special

# %% [markdown]
# Запуск скриптов должен осуществляться под Linux, так как на Windows многопоточность реализована немного по-другому,
# чем это сделали авторы модуля Uncertainpy.

# %%
from uq_izhikevich_function import go
import os
import shutil

# %% [markdown]
# Импортируем необходимые модули. Функция go запускает обработку модели. Подробное описание функции go вместе с используемыми параметрами представлено в файле uq_izhikevich_function.ipynb.

# %%
path_to_results = "results"

tests = {
    "RS": [["a", 0.02, None],
          ["b", 0.2, None],
          ["c", -65, None],
          ["d", 8, None]],
    "IB": [["a", 0.02, None],
          ["b", 0.2, None],
          ["c", -55, None],
          ["d", 4, None]],
    "CH": [["a", 0.02, None],
          ["b", 0.2, None],
          ["c", -50, None],
          ["d", 2, None]],
    "FS": [["a", 0.1, None],
          ["b", 0.2, None],
          ["c", -65, None],
          ["d", 8, None]],
   "LTS": [["a", 0.02, None],
          ["b", 0.25, None],
          ["c", -65, None],
          ["d", 8, None]]
      
}

# %% [markdown]
# Задаем параметры для 5 различных моделей с параметрами, указанными в статье
# Simple Model of Spiking Neuron, Eugene M. Izhikevich (izhikevich.pdf).
#
# ![models.png](attachment:models.png)

# %% [markdown]
# ВНИМАНИЕ: Запускать следующие ячейки только для пересчета результатов. Все результаты удалятся, а новых потом ждать очень долго.

# %%
input("Вы уверены, что хотите стереть папку results?")

if(os.path.isdir(path_to_results)):
    shutil.rmtree(path_to_results)
os.mkdir(path_to_results)

# %% [markdown]
# Подготавливаем папку, в которой будем сохранять результаты.

# %%
for model in tests:
    go(tests[model])
    shutil.copytree("figures", os.path.join(path_to_results, model))
# Out:
# Running model: 100%|██████████| 142/142 [00:01<00:00, 124.19it/s]
# Calculating PC for each feature:  22%|██▏       | 2/9 [00:04<00:16,  2.39s/it]--- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 712, in polynomial_chaos
#     **custom_kwargs
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 1361, in polynomial_chaos
#     allow_incomplete=allow_incomplete)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 649, in create_PCE_collocation
#     masked_evaluations, mask, masked_nodes = self.create_masked_nodes(data, feature, nodes)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 352, in create_masked_nodes
#     masked_evaluations, mask = self.create_masked_evaluations(data, feature)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 321, in create_masked_evaluations
#     "parameter combinations.")
#   File "/usr/lib/python3.6/logging/__init__.py", line 1320, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'average_AHP_depth: only yields results for 107/142 parameter combinations.'
# Arguments: ()
# WARNING - average_AHP_depth: only yields results for 107/142 parameter combinations.
# Calculating PC for each feature: 100%|██████████| 9/9 [00:12<00:00,  1.26s/it]
# Calculating statistics from PCE: 100%|██████████| 9/9 [07:20<00:00, 48.90s/it]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 721, in polynomial_chaos
#     self.save(filename, folder=data_folder)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 1230, in save
#     logger.info("Saving data as: {}".format(save_path))
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'Saving data as: data/izhikevich.h5'
# Arguments: ()
# Saving data as: data/izhikevich.h5
# Running model: 100%|██████████| 142/142 [00:01<00:00, 121.02it/s]
# Calculating PC for each feature: 100%|██████████| 9/9 [00:09<00:00,  1.00s/it]
# Calculating statistics from PCE: 100%|██████████| 9/9 [07:32<00:00, 49.39s/it]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 721, in polynomial_chaos
#     self.save(filename, folder=data_folder)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 1230, in save
#     logger.info("Saving data as: {}".format(save_path))
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'Saving data as: data/izhikevich.h5'
# Arguments: ()
# Saving data as: data/izhikevich.h5
# Running model: 100%|██████████| 142/142 [00:01<00:00, 116.45it/s]
# Calculating PC for each feature:  11%|█         | 1/9 [00:02<00:16,  2.12s/it]--- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 712, in polynomial_chaos
#     **custom_kwargs
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 1361, in polynomial_chaos
#     allow_incomplete=allow_incomplete)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 649, in create_PCE_collocation
#     masked_evaluations, mask, masked_nodes = self.create_masked_nodes(data, feature, nodes)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 352, in create_masked_nodes
#     masked_evaluations, mask = self.create_masked_evaluations(data, feature)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 321, in create_masked_evaluations
#     "parameter combinations.")
#   File "/usr/lib/python3.6/logging/__init__.py", line 1320, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'accommodation_index: only yields results for 130/142 parameter combinations.'
# Arguments: ()
# WARNING - accommodation_index: only yields results for 130/142 parameter combinations.
# Calculating PC for each feature:  22%|██▏       | 2/9 [00:03<00:13,  1.88s/it]--- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 712, in polynomial_chaos
#     **custom_kwargs
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 1361, in polynomial_chaos
#     allow_incomplete=allow_incomplete)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 649, in create_PCE_collocation
#     masked_evaluations, mask, masked_nodes = self.create_masked_nodes(data, feature, nodes)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 352, in create_masked_nodes
#     masked_evaluations, mask = self.create_masked_evaluations(data, feature)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 321, in create_masked_evaluations
#     "parameter combinations.")
#   File "/usr/lib/python3.6/logging/__init__.py", line 1320, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'average_AHP_depth: only yields results for 127/142 parameter combinations.'
# Arguments: ()
# WARNING - average_AHP_depth: only yields results for 127/142 parameter combinations.
# Calculating PC for each feature: 100%|██████████| 9/9 [00:07<00:00,  1.43it/s]
# Calculating statistics from PCE: 100%|██████████| 9/9 [07:21<00:00, 49.54s/it]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 721, in polynomial_chaos
#     self.save(filename, folder=data_folder)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 1230, in save
#     logger.info("Saving data as: {}".format(save_path))
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'Saving data as: data/izhikevich.h5'
# Arguments: ()
# Saving data as: data/izhikevich.h5
# Running model: 100%|██████████| 142/142 [00:01<00:00, 118.49it/s]
# Calculating PC for each feature: 100%|██████████| 9/9 [00:08<00:00,  1.01it/s]
# Calculating statistics from PCE: 100%|██████████| 9/9 [07:57<00:00, 53.29s/it]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 721, in polynomial_chaos
#     self.save(filename, folder=data_folder)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 1230, in save
#     logger.info("Saving data as: {}".format(save_path))
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'Saving data as: data/izhikevich.h5'
# Arguments: ()
# Saving data as: data/izhikevich.h5
# Running model: 100%|██████████| 142/142 [00:01<00:00, 112.07it/s]
# Calculating PC for each feature:  22%|██▏       | 2/9 [00:04<00:17,  2.55s/it]--- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 712, in polynomial_chaos
#     **custom_kwargs
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 1361, in polynomial_chaos
#     allow_incomplete=allow_incomplete)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 649, in create_PCE_collocation
#     masked_evaluations, mask, masked_nodes = self.create_masked_nodes(data, feature, nodes)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 352, in create_masked_nodes
#     masked_evaluations, mask = self.create_masked_evaluations(data, feature)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/core/uncertainty_calculations.py", line 321, in create_masked_evaluations
#     "parameter combinations.")
#   File "/usr/lib/python3.6/logging/__init__.py", line 1320, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'average_AHP_depth: only yields results for 141/142 parameter combinations.'
# Arguments: ()
# WARNING - average_AHP_depth: only yields results for 141/142 parameter combinations.
# Calculating PC for each feature: 100%|██████████| 9/9 [00:12<00:00,  1.22s/it]
# Calculating statistics from PCE: 100%|██████████| 9/9 [07:41<00:00, 51.35s/it]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 749, in _callmethod
#     conn = self._tls.connection
# AttributeError: 'ForkAwareLocal' object has no attribute 'connection'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 134, in emit
#     self.send(s)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 114, in send
#     self.queue.put_nowait(s)
#   File "<string>", line 2, in put_nowait
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 753, in _callmethod
#     self._connect()
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/managers.py", line 740, in _connect
#     conn = self._Client(self._token.address, authkey=self._authkey)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 490, in Client
#     c = SocketClient(address)
#   File "/home/vav/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 617, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# Call stack:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vav/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vav/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vav/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vav/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-06ee798cdcf2>", line 2, in <module>
#     go(tests[model])
#   File "/home/vav/Development/izhikevich/uq_izhikevich_function.py", line 27, in go
#     data = UQ.quantify()
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 430, in quantify
#     **custom_kwargs)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 721, in polynomial_chaos
#     self.save(filename, folder=data_folder)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/uncertainty.py", line 1230, in save
#     logger.info("Saving data as: {}".format(save_path))
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/home/vav/.local/lib/python3.6/site-packages/uncertainpy/utils/logger.py", line 138, in emit
#     self.handleError(record)
# Message: 'Saving data as: data/izhikevich.h5'
# Arguments: ()
# Saving data as: data/izhikevich.h5

# %% [markdown]
# Для каждой модели производим вычисления. В ходе выполения программа ругается, но результаты выдает.

# %% [markdown]
# Resgular Spiking (RS)
# ![izhikevich_prediction-interval.png](attachment:izhikevich_prediction-interval.png)

# %% [markdown]
# Intrinsically Bursting (IB)
# ![izhikevich_prediction-interval.png](attachment:izhikevich_prediction-interval.png)

# %% [markdown]
# Chattering (CH)
# ![izhikevich_prediction-interval.png](attachment:izhikevich_prediction-interval.png)

# %% [markdown]
# Fast Spiking (FS)
# ![izhikevich_prediction-interval.png](attachment:izhikevich_prediction-interval.png)

# %% [markdown]
# Low-threshold spiking (LTS)
# ![izhikevich_prediction-interval.png](attachment:izhikevich_prediction-interval.png)
